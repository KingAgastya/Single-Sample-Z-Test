# %% [markdown]
# <a href="https://colab.research.google.com/github/KingAgastya/Single-Sample-Z-Test/blob/main/Single_sample_z_tests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
fileData = files.upload()

# %%
import plotly.figure_factory as ff
import pandas as pd
import csv
import random
import statistics as st

fileInfo = pd.read_csv('student_marks.csv')

data = fileInfo['Math_score'].tolist()
fig = ff.create_distplot([data], ['Marks'])
fig.show()

mean = st.mean(data)
median = st.median(data)
mode = st.mode(data)
stdev = st.stdev(data)

print(mean, stdev)

# %%
means = []

def random_means(n):
  numbers = []
  for i in range(0, n):
    random_index = random.randint(0, (len(data) - 1))
    numbers.append(data[random_index])
  
  mean = st.mean(numbers)
  return mean

def setup(num):
  for j in range(0, num):
    meanData = random_means(30)
    means.append(meanData)

  print(means)

setup(100)
#fig = ff.create_distplot([means], ['Marks'])
#fig.show()

mean = st.mean(means)
stdev = st.stdev(means)

print(mean, stdev)

sd1Start, sd1End = mean - stdev, mean + stdev
sd2Start, sd2End = mean - (2*stdev), mean + (2*stdev)
sd3Start, sd3End = mean - (3*stdev), mean + (3*stdev)

import plotly.graph_objects as go

fig = ff.create_distplot([means], ['Marks'], show_hist = False)

fig.add_trace(go.Scatter(x = [mean, mean], y = [0, 0.17], mode = 'lines', name = 'Mean'))

fig.add_trace(go.Scatter(x = [sd1Start, sd1Start], y = [0, 0.17], mode = 'lines', name = 'std1'))
fig.add_trace(go.Scatter(x = [sd1End, sd1End], y = [0, 0.17], mode = 'lines', name = 'std1'))

fig.add_trace(go.Scatter(x = [sd2Start, sd2Start], y = [0, 0.17], mode = 'lines', name = 'std2'))
fig.add_trace(go.Scatter(x = [sd2End, sd2End], y = [0, 0.17], mode = 'lines', name = 'std2'))

fig.add_trace(go.Scatter(x = [sd3Start, sd3Start], y = [0, 0.17], mode = 'lines', name = 'std3'))
fig.add_trace(go.Scatter(x = [sd3End, sd3End], y = [0, 0.17], mode = 'lines', name = 'std1'))

fig.show()

# %%
from google.colab import files
intervention_1 = files.upload()

# %%
# Intervention 1

fileInfo = pd.read_csv('intervention1.csv')
data_1 = fileInfo['Math_score'].tolist()

mean_1 = st.mean(data_1)
stdev_1 = st.stdev(data_1)

z_score_1 = (mean_1 - mean)/stdev

import plotly.graph_objects as go
fig = ff.create_distplot([means], ['Scores'], show_hist = False)

fig.add_trace(go.Scatter(x = [mean, mean], y = [0, 0.17], mode = 'lines', name = 'Mean'))

fig.add_trace(go.Scatter(x = [sd1Start, sd1Start], y = [0, 0.17], mode = 'lines', name = 'sd1'))
fig.add_trace(go.Scatter(x = [sd1End, sd1End], y = [0, 0.17], mode = 'lines', name = 'sd1'))

fig.add_trace(go.Scatter(x = [sd2Start, sd2Start], y = [0, 0.17], mode = 'lines', name = 'sd2'))
fig.add_trace(go.Scatter(x = [sd2End, sd2End], y = [0, 0.17], mode = 'lines', name = 'sd2'))

fig.add_trace(go.Scatter(x = [sd3Start, sd3Start], y = [0, 0.17], mode = 'lines', name = 'sd3'))
fig.add_trace(go.Scatter(x = [sd3End, sd3End], y = [0, 0.17], mode = 'lines', name = 'sd3'))

fig.add_trace(go.Scatter(x = [mean_1, mean_1], y = [0, 0.17], mode = 'lines', name = 'Mean_1'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="
" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-88974e32-2adf-47da-a1af-9d2e0b8aa3ad">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving intervention2.csv to intervention2.csv

# %%
# Intervention 2

fileInfo = pd.read_csv('intervention2.csv')
data_2 = fileInfo['Math_score'].tolist()

mean_2 = st.mean(data_2)
stdev_2 = st.stdev(data_2)

z_score_2 = (mean_2 - mean)/stdev

import plotly.graph_objects as go
fig = ff.create_distplot([means], ['Scores'], show_hist = False)

fig.add_trace(go.Scatter(x = [mean, mean], y = [0, 0.17], mode = 'lines', name = 'Mean'))

fig.add_trace(go.Scatter(x = [sd1Start, sd1Start], y = [0, 0.17], mode = 'lines', name = 'sd1'))
fig.add_trace(go.Scatter(x = [sd1End, sd1End], y = [0, 0.17], mode = 'lines', name = 'sd1'))

fig.add_trace(go.Scatter(x = [sd2Start, sd2Start], y = [0, 0.17], mode = 'lines', name = 'sd2'))
fig.add_trace(go.Scatter(x = [sd2End, sd2End], y = [0, 0.17], mode = 'lines', name = 'sd2'))

fig.add_trace(go.Scatter(x = [sd3Start, sd3Start], y = [0, 0.17], mode = 'lines', name = 'sd3'))
fig.add_trace(go.Scatter(x = [sd3End, sd3End], y = [0, 0.17], mode = 'lines', name = 'sd3'))

fig.add_trace(go.Scatter(x = [mean_2, mean_2], y = [0, 0.17], mode = 'lines', name = 'Mean_2'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="587d4a83-10b1-4639-a875-8b91c2a93fbb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("587d4a83-10b1-4639-a875-8b91c2a93fbb")) {                    Plotly.newPlot(                        "587d4a83-10b1-4639-a875-8b91c2a93fbb",                        [{"legendgroup":"Scores","marker":{"color":"rgb(31, 119, 180)"},"mode":"lines","name":"Scores","showlegend":true,"x":[61.86666666666667,61.88166666666667,61.89666666666667,61.91166666666667,61.92666666666667,61.94166666666667,61.95666666666667,61.971666666666664,61.986666666666665,62.001666666666665,62.016666666666666,62.031666666666666,62.04666666666667,62.06166666666667,62.07666666666667,62.09166666666667,62.10666666666667,62.12166666666667,62.13666666666667,62.151666666666664,62.166666666666664,62.181666666666665,62.196666666666665,62.211666666666666,62.22666666666667,62.24166666666667,62.25666666666667,62.27166666666667,62.28666666666667,62.30166666666667,62.31666666666667,62.33166666666666,62.346666666666664,62.361666666666665,62.376666666666665,62.391666666666666,62.406666666666666,62.42166666666667,62.43666666666667,62.45166666666667,62.46666666666667,62.48166666666667,62.49666666666667,62.51166666666666,62.526666666666664,62.541666666666664,62.556666666666665,62.571666666666665,62.586666666666666,62.60166666666667,62.61666666666667,62.63166666666667,62.64666666666667,62.66166666666667,62.67666666666667,62.69166666666666,62.70666666666666,62.721666666666664,62.736666666666665,62.751666666666665,62.766666666666666,62.781666666666666,62.79666666666667,62.81166666666667,62.82666666666667,62.84166666666667,62.85666666666667,62.87166666666667,62.88666666666666,62.901666666666664,62.916666666666664,62.931666666666665,62.946666666666665,62.961666666666666,62.97666666666667,62.99166666666667,63.00666666666667,63.02166666666667,63.03666666666667,63.05166666666667,63.06666666666666,63.08166666666666,63.096666666666664,63.111666666666665,63.126666666666665,63.141666666666666,63.156666666666666,63.17166666666667,63.18666666666667,63.20166666666667,63.21666666666667,63.23166666666667,63.24666666666666,63.26166666666666,63.276666666666664,63.291666666666664,63.306666666666665,63.321666666666665,63.336666666666666,63.35166666666667,63.36666666666667,63.38166666666667,63.39666666666667,63.41166666666667,63.42666666666666,63.44166666666666,63.45666666666666,63.471666666666664,63.486666666666665,63.501666666666665,63.516666666666666,63.531666666666666,63.54666666666667,63.56166666666667,63.57666666666667,63.59166666666667,63.60666666666667,63.62166666666666,63.63666666666666,63.651666666666664,63.666666666666664,63.681666666666665,63.696666666666665,63.711666666666666,63.72666666666667,63.74166666666667,63.75666666666667,63.77166666666667,63.78666666666666,63.80166666666666,63.81666666666666,63.83166666666666,63.846666666666664,63.861666666666665,63.876666666666665,63.891666666666666,63.906666666666666,63.92166666666667,63.93666666666667,63.95166666666667,63.96666666666667,63.98166666666666,63.99666666666666,64.01166666666667,64.02666666666667,64.04166666666667,64.05666666666667,64.07166666666666,64.08666666666666,64.10166666666666,64.11666666666666,64.13166666666666,64.14666666666666,64.16166666666666,64.17666666666666,64.19166666666666,64.20666666666666,64.22166666666666,64.23666666666666,64.25166666666667,64.26666666666667,64.28166666666667,64.29666666666667,64.31166666666667,64.32666666666667,64.34166666666667,64.35666666666667,64.37166666666667,64.38666666666667,64.40166666666667,64.41666666666667,64.43166666666667,64.44666666666666,64.46166666666666,64.47666666666666,64.49166666666666,64.50666666666666,64.52166666666666,64.53666666666666,64.55166666666666,64.56666666666666,64.58166666666666,64.59 ...

# %%
from google.colab import files
intervention_3 = files.upload()
# Out:
#      <input type="file" id="files-3a22192f-a664-43f1-a41e-d0c2d15a768a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3a22192f-a664-43f1-a41e-d0c2d15a768a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving intervention3.csv to intervention3.csv

# %%
# Intervention 3

fileInfo = pd.read_csv('intervention3.csv')
data_3 = fileInfo['Math_score'].tolist()

mean_3 = st.mean(data_3)
stdev_3 = st.stdev(data_3)
z_score_3 = (mean_3 - mean)/stdev

import plotly.graph_objects as go
fig = ff.create_distplot([means], ['Scores'], show_hist = False)

fig.add_trace(go.Scatter(x = [mean, mean], y = [0, 0.17], mode = 'lines', name = 'Mean'))

fig.add_trace(go.Scatter(x = [sd1Start, sd1Start], y = [0, 0.17], mode = 'lines', name = 'sd1'))
fig.add_trace(go.Scatter(x = [sd1End, sd1End], y = [0, 0.17], mode = 'lines', name = 'sd1'))

fig.add_trace(go.Scatter(x = [sd2Start, sd2Start], y = [0, 0.17], mode = 'lines', name = 'sd2'))
fig.add_trace(go.Scatter(x = [sd2End, sd2End], y = [0, 0.17], mode = 'lines', name = 'sd2'))

fig.add_trace(go.Scatter(x = [sd3Start, sd3Start], y = [0, 0.17], mode = 'lines', name = 'sd3'))
fig.add_trace(go.Scatter(x = [sd3End, sd3End], y = [0, 0.17], mode = 'lines', name = 'sd3'))

fig.add_trace(go.Scatter(x = [mean_3, mean_3], y = [0, 0.17], mode = 'lines', name = 'Mean_3'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="945086f6-c0c5-421a-8808-00fbcf0dd0e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("945086f6-c0c5-421a-8808-00fbcf0dd0e9")) {                    Plotly.newPlot(                        "945086f6-c0c5-421a-8808-00fbcf0dd0e9",                        [{"legendgroup":"Scores","marker":{"color":"rgb(31, 119, 180)"},"mode":"lines","name":